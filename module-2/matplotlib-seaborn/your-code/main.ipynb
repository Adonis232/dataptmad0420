# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1


plt.plot(x,y,'r--', linewidth= 1.0)
plt.plot(x,z,'g^', linewidth= 2)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, axes  = plt.subplots(nrows=1, ncols=2, figsize=(5, 5))
axes[0].plot(x,y, 'r-')
axes[1].plot(x,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, axes  = plt.subplots(nrows=1, ncols=2, figsize=(5, 5))
axes[0].set_title('Multiplication')
axes[1].set_title('Square')
axes[0].plot(x,y,'g+')
axes[1].plot(x,z)

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
a = np.arange(0,100,1)
x = a ** 2
y = np.exp(a)

fig, axes = plt.subplots(ncols=1, nrows=2, figsize=(6,6))
axes[0].plot(a,x,'r-')
axes[1].plot(a,y)
axes[1].set_yscale('log')
axes[1].set_xscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig, axes = plt.subplots(ncols=1, nrows=2, figsize=(4,4))

axes[0].plot(a,x,label='Multiplied by 2')
plt.legend()
axes[1].plot(a,y,label='Exponential')
axes[1].set_yscale('log')
axes[1].set_xscale('log')
plt.legend()

#missing legend on axes[0]
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('/home/emmanuel/Downloads/fitbit2.csv')
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

fitbit.set_index('Months_encoded').drop('Months').plot(figsize=(12, 4))

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-fa4e2fd7be6d> in <module>
#       2 # your code here
#       3
# ----> 4 fitbit.set_index('Months_encoded').drop('Months').plot(figsize=(12, 4))
#       5
#       6 # MEDIAN STEPS BY WORK_OR_WEEKEND
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
#steps_avg = sum(fitbit['Steps'])/sum(fitbit['Months_encoded'])
#fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(12,4))
#ax.plot(steps_avg, Months_encoded)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig, axs = plt.subplots(nrows = 12, ncols=4, figsize= (12, 4))

for i 
#tryals

# %%
fig = plt.figure(figsize=(16, 16))
ax1 = plt.subplot2grid((3, 3), (0, 0), colspan=3)
ax2 = plt.subplot2grid((3, 3), (1, 0), colspan=3)
ax3 = plt.subplot2grid((3, 3), (1, 2), colspan=3)

for ax in [ax1, ax2, ax3]:
    fitbit.set_index('')
    #tryals
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-4c7c909b8dfc> in <module>
#       5
#       6 for ax in [ax1, ax2, ax3]:
# ----> 7     fitbit.set_index('')
#       8     #tryals
#
# ~/miniconda3/envs/ironhack_env/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of [''] are in the columns"

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('/home/emmanuel/Downloads/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['float64', 'int64']).fillna(0)

#filled nan for 0.0
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       0.0       3  29.513190      0      0    8.0500
# 1305         1306       0.0       1  39.000000      0      0  108.9000
# 1306         1307       0.0       3  38.500000      0      0    7.2500
# 1307         1308       0.0       3  29.513190      0      0    8.0500
# 1308         1309       0.0       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(include='object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

#print(plt.style.available)
titanic.plot(figsize=(12, 6),alpha=0.5)
plt.style.use('classic')

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic[['Age']].plot(kind='hist', figsize=(12, 4));

# %%
#Just trying to use it on a dataframe, Im not really using it 
ages = pd.Series(titanic['Age'])

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
titanic['Age'].hist(bins=10, alpha= 0.5);
titanic['Age'].hist(bins=20, alpha= 0.5);
titanic['Age'].hist(bins=50, alpha= 0.5);


#not finished , separate in 3 plots left. Done

# %%
#Here I tried to show them in 3 deffirent graphs, and it works but I dont know why I get deffirent values on 'y' axes, and why I dont get 
#the title, and get the 0.5 and 1.0

# %%
fig, ax = plt.subplots(1,3, figsize=(12, 6))
sns.distplot(titanic['Age'].values, bins= 10, kde = False, ax=ax[0])
ax[0].set_title('10 bins')
sns.distplot(titanic['Age'].values, bins= 20, kde = False, ax=ax[1])
ax[1].set_title('20 bins')
sns.distplot(titanic['Age'].values, bins= 50, kde = False, ax=ax[2])
ax[2].set_title('50 bins')
# Out:
# Text(0.5, 1.0, '50 bins')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

The bins's size affect the hability we have in this case to see
more ages, the more bins we have the more ages we are able to see
we can see that ppl around 30 and 25 died in the same number
when we put the 50 bins, if we only used 10 bins we could 
only see that the most affect int this tragedy were around 28/32.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic['Age'],bins=90)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 
#getting the serie that is gender and counting unique female and male.
# your code here

titanic['Gender'].value_counts().plot.pie()

#we could put the code "titanic['Gender'].value_counts()" in a variable to use more than once

# %%
# Method 2 - seaborn
# your code here

sns.catplot(x='Gender',kind='count',data=titanic);

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.distplot(titanic['Pclass'],rug=True);
#titanic['Pclass'].hist(bins=3)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
titanic.Age.max()
titanic.Age.min()
titanic.Age.mean()
titanic.Age.std()
titanic.Age.median()
titanic.Age.quantile(.25)
titanic.Age.quantile(.75)
titanic['Age'].describe(include='all')
# Out:
# count    1309.000000
# mean       29.879186
# std        13.448335
# min         0.170000
# 25%        22.000000
# 50%        28.500000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
titanic[['Age']].boxplot(figsize=(8,8));

# %%
"""
your comments here

The boxplot its the best option since it shos us 
everything on just one plot and its easy to understand
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
It tells us that the age it's really spread out, we have newborns and ppl of really old age
, majority of passengers were between early 20's and late 30's, and that ages over 58/59
are rare
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
bar_plot = sns.violinplot(x='Gender',y='Age',gridsize=100,palette="ch:2.5,-.2,dark=.3",data=titanic)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here

The violin plot it helps with visualization, the best one 
in this case would be a population pyramind, but it was giving me so many errors
that I chose to do this in a violin plot, thats the most
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic.plot(x='Age',y='Fare',style='o')

#missing the relational line

# %%
# Method 2 - seaborn
# your code here

corr = titanic[['Age','Fare']].corr()
               
mask = np.triu(np.ones_like(corr, dtype=np.bool))
mask[np.triu_indices_from(mask)] = True
               
fig, ax = plt.subplots(figsize=(12,12))

cmap = sns.diverging_palette(1,5,as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, annot=True, vmax=1, center=0,
           square=True, linewidth=1,cbar_kws={'shrink':.5})

##########


sns.lmplot(data=titanic,x='Age',y='Fare',hue='Gender')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.pairplot(titanic)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here

fare-age

"""
titanic['SibSp']
# Out:
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    1
# Name: SibSp, Length: 1309, dtype: int64

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
titanic[['Age','Pclass']]
# Out:
#             Age  Pclass
# 0     22.000000       3
# 1     38.000000       1
# 2     26.000000       3
# 3     35.000000       1
# 4     35.000000       3
# ...         ...     ...
# 1304  29.513190       3
# 1305  39.000000       1
# 1306  38.500000       3
# 1307  29.513190       3
# 1308  25.315435       3
#
# [1309 rows x 2 columns]

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here


sns.FacetGrid(titanic,col='Age',row='Gender')
